# %%
from IPython.display import Image

# %% [markdown]
# ### Выборочный показ дашборда
# #### Ссылка на полный проект: https://datalens.yandex/k5ibtz426y646

# %%
# Просмотр части Дашборда (overview)

Image(filename="/Users/sabicklove/Desktop/part.png")

# %%
# Средняя выручка с одного заказа

# Формула в показателе - sum([revenue])/sum([tickets_count])

Image(filename="/Users/sabicklove/Desktop/avg_rev_order.png")

# %%
# Недельная динамика выручки с заказа

# Х-формула - DATETRUNC([created_dt_msk], "week")
# Y-формула - sum([revenue])

Image(filename="/Users/sabicklove/Desktop/weekly_revenue.png")

# %%
# Выручка за весь период в разрезе типа устройств

# Выручка - SUM([revenue])

Image(filename="/Users/sabicklove/Desktop/device_type.png")

# %%
# Топ-5 площадок


# Формулы в столбцах

# Общее значение выручки - SUM([revenue])
# Кол-во заказов - COUNT([order_id])
# Среднее количество билетов в заказе - SUM([tickets_count]) / COUNT([order_id])
# Средняя выручка с одного билета - SUM([revenue]) / SUM([tickets_count])

Image(filename="/Users/sabicklove/Desktop/top5_spots.png")
